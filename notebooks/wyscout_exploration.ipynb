# %%
import os
import os.path as osp
if osp.split(os.getcwd())[-1] == 'notebooks':
    os.chdir('..')

os.getcwd()
# Out:
# 'e:\\Edoardo\\Education\\SportDataCampus\\ScoutingAgent'

# %%
import wyscout as wy

# %% [markdown]
# # Fixtures

# %%
#La Liga 25/26
season_id = 191659

# %%
fixtures = wy.get_season_fixtures(season_id)
fixtures[-1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 fixtures = wy.get_season_fixtures(season_id)
# ----> 2 fixtures[-1]
#
# KeyError: -1

# %%
from wyscout import get_match_events


get_match_events(5718124)['events']
# Out:
# {'meta': [],
#  'events': [{'id': 2927833235,
#    'matchId': 5718124,
#    'matchPeriod': '1H',
#    'minute': 0,
#    'second': 2,
#    'matchTimestamp': '00:00:02.541',
#    'videoTimestamp': '3.541425',
#    'relatedEventId': 2927833236,
#    'type': {'primary': 'pass',
#     'secondary': ['back_pass', 'short_or_medium_pass']},
#    'location': {'x': 51, 'y': 51},
#    'team': {'id': 692, 'name': 'Celta de Vigo', 'formation': '3-4-3'},
#    'opponentTeam': {'id': 675, 'name': 'Real Madrid', 'formation': '5-4-1'},
#    'player': {'id': 590503, 'name': 'Ilaix Moriba', 'position': 'LCMF'},
#    'pass': {'accurate': True,
#     'angle': 174,
#     'height': None,
#     'length': 19,
#     'recipient': {'id': 8032, 'name': 'Marcos Alonso', 'position': 'LCB3'},
#     'endLocation': {'x': 33, 'y': 55}},
#    'shot': None,
#    'groundDuel': None,
#    'aerialDuel': None,
#    'infraction': None,
#    'carry': None,
#    'possession': {'id': 2927833235,
#     'duration': '3.5260725',
# ...
